# %% [markdown]
# # Es 4.1

# %% [markdown]
# In questa esercitazione è stato chiesto di modificare un codice di Dinamica Molecolare. <br>
# La prima richiesta è stata quella di implementare la possibilità di far ripartire la simulazione da una situazione precedentemnte modificate (diversa dalla situazione cristallina perfetta). <br>
# Sono state riscalate le temperature per farle corrispondere alla temperatura di target, lasciando il sistema funzionare per 1000 passi 4 volte, ogni volta partendo dalla configurazione raggiunta nella precedente e facendo corrispondere le velocità al fine di compensare la caduta di energia cinetica associata al raggiungimento dell'equilibrio termico del sistema.<br>
# È possibile vedere dal grafici qui sotto che il meccanismo di riavvio, ottenuto ridimensionando le velocità, funziona con la generic phase.
# Tutte le misure sono espresse in unità Lennard-Jones.

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

plt.rcParams['figure.figsize'] = [16,9]
temp = np.loadtxt("output_temp_generic.dat", usecols=(0), unpack='true')
plt.plot(temp, label="Temperature")
u = np.loadtxt("output_epot_generic.dat", usecols=(0), unpack='true')
plt.plot(u, label="Potential Energy")
k = np.loadtxt("output_ekin_generic.dat", usecols=(0), unpack='true')
plt.plot(k, label="Kinetic Energy")
t = np.loadtxt("output_etot_generic.dat", usecols=(0), unpack='true')
plt.plot(t, label="Total Energy")
plt.title("Es 4.1")
plt.xlabel('Measure')
plt.ylabel('Value')
plt.grid(1)
plt.legend()
plt.show()

# %% [markdown]
# # Es 4.2

# %% [markdown]
# La seconda richiesta dell'esercitazione era di aggiungere il data blocking per misurare le proprietà medie e i loro errori statistici.

# %%
block,temp,error = np.loadtxt("ave_epot_generic.dat", usecols=(0,1,2), delimiter=" ", unpack='true')
plt.errorbar(block, temp, yerr=error, label="Potential Energy")
plt.title("Es 4.2")
plt.xlabel('Block Number')
plt.ylabel('Potential Energy')
plt.grid(1)
plt.legend()
plt.show()

# %%
block,temp,error = np.loadtxt("ave_ekin_generic.dat", usecols=(0,1,2), delimiter=" ", unpack='true')
plt.errorbar(block, temp, yerr=error, label="Kinetic Energy")
plt.title("Es 4.2")
plt.xlabel('Block Number')
plt.ylabel('Kinetic Energy')
plt.grid(1)
plt.legend()
plt.show()

# %%
block,temp,error = np.loadtxt("ave_etot_generic.dat", usecols=(0,1,2), delimiter=" ", unpack='true')
plt.errorbar(block, temp, yerr=error, label="Total Energy")
plt.title("Es 4.2")
plt.xlabel('Block Number')
plt.ylabel('Total Energy')
plt.grid(1)
plt.legend(loc="best")
plt.show()

# %%
block,temp,error = np.loadtxt("ave_temp_generic.dat", usecols=(0,1,2), delimiter=" ", unpack='true')
plt.errorbar(block, temp, yerr=error, label="Temperature")
plt.title("Es 4.2")
plt.xlabel('Block Number')
plt.ylabel('Temperature')
plt.grid(1)
plt.legend(loc="best")
plt.show()

# %% [markdown]
# # Es 4.3

# %% [markdown]
# Nella sezione seguente sono presentati i grafici di alcune proprietà termodinamiche dell'Argon in fase solida, liquida e gassosa. Si noti che le misure sono espresse in unità fisiche reali; le energie sono in eV, la temperatura è in K e la pressione è in atm.

# %% [markdown]
# # ARGON

# %% [markdown]
# ## Gas

# %%
block,temp,error = np.loadtxt("argon_ave_epot_gas.dat", usecols=(0,1,2), delimiter=";", unpack='true')
plt.errorbar(block, temp, yerr=error, label="Potential Energy")
plt.title("Gas Argon Potential Energy")
plt.xlabel('Block Number')
plt.ylabel('Potential Energy [eV]')
plt.grid(1)
plt.legend(loc="best")
plt.show()

# %%
block,temp,error = np.loadtxt("argon_ave_ekin_gas.dat", usecols=(0,1,2), delimiter=";", unpack='true')
plt.errorbar(block, temp, yerr=error, label="Kinetic Energy")
plt.title("Gas Argon Kinetic Energy")
plt.xlabel('Block Number')
plt.ylabel('Kinetic Energy [eV]')
plt.grid(1)
plt.legend(loc="best")
plt.show()

# %%
block,temp,error = np.loadtxt("argon_ave_etot_gas.dat", usecols=(0,1,2), delimiter=";", unpack='true')
plt.errorbar(block, temp, yerr=error, label="Total Energy")
plt.title("Gas Argon Total Energy")
plt.xlabel('Block Number')
plt.ylabel('Total Energy [eV]')
plt.grid(1)
plt.legend(loc="best")
plt.show()

# %%
block,temp,error = np.loadtxt("argon_ave_temp_gas.dat", usecols=(0,1,2), delimiter=";", unpack='true')
plt.errorbar(block, temp, yerr=error, label="Temperature")
plt.title("Gas Argon Temperature")
plt.xlabel('Block Number')
plt.ylabel('Temperature [K]')
plt.grid(1)
plt.legend(loc="best")
plt.show()

# %% [markdown]
# ## Liquid

# %%
block,temp,error = np.loadtxt("argon_ave_epot_liquid.dat", usecols=(0,1,2), delimiter=";", unpack='true')
plt.errorbar(block, temp, yerr=error, label="Potential Energy")
plt.title("Liquid Argon Potential Energy")
plt.xlabel('Block Number')
plt.ylabel('Potential Energy [eV]')
plt.grid(1)
plt.legend(loc="best")
plt.show()

# %%
block,temp,error = np.loadtxt("argon_ave_ekin_liquid.dat", usecols=(0,1,2), delimiter=";", unpack='true')
plt.errorbar(block, temp, yerr=error, label="Kinetic Energy")
plt.title("Liquid Argon Kinetic Energy")
plt.xlabel('Block Number')
plt.ylabel('Kinetic Energy [eV]')
plt.grid(1)
plt.legend(loc="best")
plt.show()

# %%
block,temp,error = np.loadtxt("argon_ave_etot_liquid.dat", usecols=(0,1,2), delimiter=";", unpack='true')
plt.errorbar(block, temp, yerr=error, label="Total Energy")
plt.title("Liquid Argon Total Energy")
plt.xlabel('Block Number')
plt.ylabel('Total Energy [eV]')
plt.grid(1)
plt.legend(loc="best")
plt.show()

# %%
block,temp,error = np.loadtxt("argon_ave_temp_liquid.dat", usecols=(0,1,2), delimiter=";", unpack='true')
plt.errorbar(block, temp, yerr=error, label="Temperature")
plt.title("Liquid Argon Temperature")
plt.xlabel('Block Number')
plt.ylabel('Temperature [K]')
plt.grid(1)
plt.legend(loc="best")
plt.show()

# %% [markdown]
# ## Solid

# %% [markdown]
# (non riesco a capire come mai le proprietà termodinamiche nella fase solida abbiano questa estrema regolarità, suppongo un errore nella equilibrazione precedente alla "presa dati")

# %%
block,temp,error = np.loadtxt("argon_ave_epot_solid.dat", usecols=(0,1,2), delimiter=";", unpack='true')
plt.errorbar(block, temp, yerr=error, label="Potential Energy")
plt.title("Solid Argon Potential Energy")
plt.xlabel('Block Number')
plt.ylabel('Potential Energy [eV]')
plt.grid(1)
plt.legend(loc="best")
plt.show()

# %%
block,temp,error = np.loadtxt("argon_ave_ekin_solid.dat", usecols=(0,1,2), delimiter=";", unpack='true')
plt.errorbar(block, temp, yerr=error, label="Kinetic Energy")
plt.title("Solid Argon Kinetic Energy")
plt.xlabel('Block Number')
plt.ylabel('Kinetic Energy [eV]')
plt.grid(1)
plt.legend(loc="best")
plt.show()

# %%
block,temp,error = np.loadtxt("argon_ave_etot_solid.dat", usecols=(0,1,2), delimiter=";", unpack='true')
plt.errorbar(block, temp, yerr=error, label="Total Energy")
plt.title("Solid Argon Total Energy")
plt.xlabel('Block Number')
plt.ylabel('Total Energy [eV]')
plt.grid(1)
plt.legend(loc="best")
plt.show()

# %%
block,temp,error = np.loadtxt("argon_ave_temp_solid.dat", usecols=(0,1,2), delimiter=";", unpack='true')
plt.errorbar(block, temp, yerr=error, label="Temperature")
plt.title("Solid Argon Temperature")
plt.xlabel('Block Number')
plt.ylabel('Temperature [K]')
plt.grid(1)
plt.legend(loc="best")
plt.show()
